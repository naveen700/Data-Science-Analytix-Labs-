# %%
import pandas  as pd
lis = [1,2,2,331,23,1,3,32,2,1,4,456,6,3]
ser1 = pd.Series(lis)

# %%
ser1
# Out:
# 0       1
# 1       2
# 2       2
# 3     331
# 4      23
# 5       1
# 6       3
# 7      32
# 8       2
# 9       1
# 10      4
# 11    456
# 12      6
# 13      3
# dtype: int64

# %%
ser1.describe()
# Out:
# count     14.000000
# mean      61.928571
# std      142.893971
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%       18.750000
# max      456.000000
# dtype: float64

# %%
ex = pd.read_csv('/home/shivay/anaconda2/DataSets/FL_insurance_sample.csv')
ex.describe()
# ex.info()
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# ...

# %%
# structural in Data Manipulation
# 1 .structural

# %%
# extracting coloumns
# 1. using dot operator
ex.policyID
type(ex.policyID)
# Out:
# pandas.core.series.Series

# %%
# Note one coloumn extracted form dataset is  series and column is series type object

# 2. use a simple[]
case1 = ex['policyID']
print case1
# Out:
# 0        119736
# 1        448094
# 2        206893
# 3        333743
# 4        172534
# 5        785275
# 6        995932
# 7        223488
# 8        433512
# 9        142071
# 10       253816
# 11       894922
# 12       422834
# 13       582721
# 14       842700
# 15       874333
# 16       580146
# 17       456149
# 18       767862
# 19       353022
# 20       367814
# 21       671392
# 22       772887
# 23       983122
# 24       934215
# 25       385951
# 26       716332
# 27       751262
# 28       633663
# 29       105851
#           ...
# 36604    792963
# 36605    367030
# 36606    594660
# 36607    360785
# 36608    847570
# 36609    196088
# 36610    166064
# 36611    507269
# 36612    335445
# 36613    451921
# 36614    859202
# 36615    584224
# 36616    603769
# 36617    575194
# 36618    708726
# 36619    645213
# 36620    175829
# 36621    546178
# 36622    938910
# 36623    592170
# 36624    827844
# 36625    876385
# 36626    167630
# 36627    241496
# ...

# %%
case2 = ex[['policyID' ,'eq_site_limit']] # multiple col can be pass as list to fetch multiple coloumns

# %%
type(case2)
# Out:
# pandas.core.frame.DataFrame

# %%
#3. use loc[] and iloc[]
# for using loc and iloc , its necessary to pass both coloumns and row
# [r,c] -> left of comma for row and right for comma for coloumn

# for all rows present we can use  : colon in place of row
ex.loc[:,["policyID","eq_site_limit"]]
# for first 10  rows
ex.loc[0:9,["policyID","eq_site_limit"]]
# Out:
#    policyID  eq_site_limit
# 0    119736       498960.0
# 1    448094      1322376.3
# 2    206893       190724.4
# 3    333743            0.0
# 4    172534            0.0
# 5    785275            0.0
# 6    995932            0.0
# 7    223488       328500.0
# 8    433512       315000.0
# 9    142071       705600.0
